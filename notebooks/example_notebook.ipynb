# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: imgkit in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (1.2.3)
# Requirement already satisfied: fastcluster in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: matplotlib in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (3.10.6)
# Requirement already satisfied: mpl-tools in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: networkx in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 5)) (3.5)
# Requirement already satisfied: pandas in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 6)) (2.3.3)
# Requirement already satisfied: pydash in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 7)) (8.0.5)
# Requirement already satisfied: scikit-learn in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 8)) (1.7.2)
# Requirement already satisfied: seaborn in /home/96v/micromamba/lib/python3.13/site-packages (from -r ../requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: six in /home/96v/micromamba/lib/python3.13/site-packages (from imgkit->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: numpy>=2 in /home/96v/micromamba/lib/python3.13/site-packages (from fastcluster->-r ../requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/96v/micromamba/lib/python3.13/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/96v/micromamba/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/96v/micromamba/lib/python3.13/site-packages (from pandas->-r ../requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: typing-extensions!=4.6.0,>3.10 in /home/96v/micromamba/lib/python3.13/site-packages (from pydash->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/96v/micromamba/lib/python3.13/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/96v/micromamba/lib/python3.13/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/96v/micromamba/lib/python3.13/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (3.6.0)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import pandas as pd
import seaborn as sns
import sys
sys.path.append("../") 
import heritability_illustrator
from heritability_illustrator.create_visualization import generate_profile_from_vcf, create_start_stop_df

# %%
start_pos = 0
stop_pos = 4_200_000

outfiles_ronn1_ME = generate_profile_from_vcf(
    "../..//variant_mapping/Bsubtilis_350strain_SNPs_final.vcf", 
    start_pos = start_pos,
    stop_pos =  stop_pos,
    class_encoding_filename = None, # '../image_data/sorted/class_encodings.xlsx'
    input_image_directory = None) 

create_start_stop_df(outfiles_ronn1_ME[0], start_pos, stop_pos, "Bsubtilis_SNPs", 0)
# Out:
# /mnt/DGX01/Personal/lanemj/projects/bacterial_qtl/heritability_illustrator/notebooks/../heritability_illustrator/create_visualization.py:184: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2['alleles'] = df['REF'] + '/' + df['ALT']
# Generating Data
# Saving Group Statistics
# Bsubtilis_350strain_SNPs_final_0_4200000_snp_matchings_by_group.tsv
# Bsubtilis_350strain_SNPs_final_0_4200000_groupings.tsv

# %%
df = pd.read_csv("Bsubtilis_350strain_SNPs_final_0_to_4200000_visualizations/Bsubtilis_350strain_SNPs_final_0_4200000_snp_matchings_by_group.tsv", sep='\t', index_col=0) 
data = df[df.columns[:-1]].loc[df.index[1:]]

# %%
colors = ['cyan', 'black']

black_to_blue_cmap = LinearSegmentedColormap.from_list('black_to_blue', colors)
sns.heatmap(data, cmap=black_to_blue_cmap)
# Out:
# <Axes: >
